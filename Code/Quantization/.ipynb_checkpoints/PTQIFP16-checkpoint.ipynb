# %%
import tensorflow as tf
import os

# =====================
# PATH
# =====================
MODEL_PATH = "baseline_mobilenetv3_final.keras"
OUTPUT_TFLITE = "baseline_mobilenetv3_fp16.tflite"

# =====================
# LOAD MODEL
# =====================
model = tf.keras.models.load_model(
    MODEL_PATH,
    compile=False
)

print("✅ Baseline FP32 model loaded")
# Out:
# ✅ Baseline FP32 model loaded

# %%
# =====================
# FP16 QUANTIZATION
# =====================
converter = tf.lite.TFLiteConverter.from_keras_model(model)

converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]

tflite_fp16 = converter.convert()

# =====================
# SAVE MODEL
# =====================
with open(OUTPUT_TFLITE, "wb") as f:
    f.write(tflite_fp16)

print("✅ FP16 TFLite model saved:", OUTPUT_TFLITE)
print("📦 Model size (MB):", round(os.path.getsize(OUTPUT_TFLITE) / (1024**2), 2))
# Out:
# INFO:tensorflow:Assets written to: C:\Users\adity\AppData\Local\Temp\tmpmhrvnmh6\assets
# INFO:tensorflow:Assets written to: C:\Users\adity\AppData\Local\Temp\tmpmhrvnmh6\assets
# Saved artifact at 'C:\Users\adity\AppData\Local\Temp\tmpmhrvnmh6'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   1635750515664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656597776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656598352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656598928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656598736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656600464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656600848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656601232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656601040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656599504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656602384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656602960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656602000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656603728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656603152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656604304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656604688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656604496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656600080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656605840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656606224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656606608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656606416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656597968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656607760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656608144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656608528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656608336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656603920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656609680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656610064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656610448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656610256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656605456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656611600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656611984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656612368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656612176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656607376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656613520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656598160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660366288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656613136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635656611216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660367440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660367824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660368208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660368016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660366672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660369360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660369744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660370128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660369936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660366864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660371280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660371664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660372048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660371856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660366096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660373200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660373776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660372816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660374544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660373968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660375120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660375504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660375312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660370896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660376656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660377040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660377424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660377232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660367056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660378576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660378960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660379344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660379152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660374736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660380496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660381072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660380112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660381840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660381264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660378192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660922960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660382032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660368976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660924688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660925072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660925456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660925264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660923920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660926608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660926992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660927376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660927184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660923344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660928528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660929104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660928144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660929872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660929296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660930448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660930832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660930640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660926224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660931984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660932368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660932752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660932560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660923152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660933904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660934288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660934672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660934480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660930064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660935824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660936400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660935440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660937168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660936592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660937744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660938128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660937936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660933520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660924304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654615504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654616080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660937360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635660936976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654617040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654617424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654617808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654617616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654616272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654618960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654619536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654618576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654620304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654619728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654620880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654621264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654621072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654616656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654622416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654622800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654623184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654622992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654615888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654624336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654624720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654625104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654624912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654620496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654626256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654626832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654625872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654627600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654627024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654628176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654628560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654628368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654623952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654629712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654630096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654630480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654630288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654615696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654628944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746955536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746956304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654631248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635654627792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746957456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746958032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746957072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746958800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746958224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746959376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746959760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746959568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746955344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746960912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746961296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746961680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746961488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746955728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746962832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746963216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746963600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746963408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746958992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746964752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746965328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746964368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746966096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746965520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746966672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746967056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746966864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746962448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746968208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746968592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746968976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746968784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746956112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746960528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1635746971280: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ FP16 TFLite model saved: baseline_mobilenetv3_fp16.tflite
# 📦 Model size (MB): 1.82

# %%
# =====================
# DISABLE XNNPACK (WAJIB DI WINDOWS)
# =====================
os.environ["TF_LITE_DISABLE_XNNPACK"] = "1"

# =====================
# LOAD INTERPRETER
# =====================
interpreter = tf.lite.Interpreter(
    model_path=OUTPUT_TFLITE
)
interpreter.allocate_tensors()

input_details  = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("✅ FP16 Interpreter ready")
print("Input :", input_details[0]["shape"], input_details[0]["dtype"])
print("Output:", output_details[0]["shape"], output_details[0]["dtype"])
# Out:
# ✅ FP16 Interpreter ready
# Input : [  1 224 224   3] <class 'numpy.float32'>
# Output: [ 1 10] <class 'numpy.float32'>
# C:\Users\adity\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

# =====================
# CONFIG
# =====================
IMG_SIZE = 224
BATCH_SIZE = 16
TEST_DIR = r"C:\Users\adity\Downloads\dataset_split_final\test"

# =====================
# TEST GENERATOR (SAMA DENGAN TRAINING)
# =====================
test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

test_gen = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

print("✅ test_gen ready")
print("Total test samples:", test_gen.samples)
# Out:
# Found 1000 images belonging to 10 classes.
# ✅ test_gen ready
# Total test samples: 1000

# %%
import time
import numpy as np

correct = 0
total = 0
times = []

for i in range(test_gen.samples):
    x_batch, y_batch = next(test_gen)
    x = x_batch[0:1]
    y = y_batch[0]

    start = time.time()
    interpreter.set_tensor(input_details[0]["index"], x.astype(np.float32))
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]["index"])
    end = time.time()

    pred = output.argmax(axis=1)[0]
    true = y.argmax()

    correct += int(pred == true)
    total += 1
    times.append(end - start)

accuracy = correct / total
avg_time = sum(times) / len(times)
fps = 1 / avg_time

print(f"✅ TFLite FP16 Accuracy : {accuracy*100:.2f}%")
print(f"⏱ Avg inference / img  : {avg_time:.6f} sec")
print(f"🚀 FPS                 : {fps:.2f}")
# Out:
# ✅ TFLite FP16 Accuracy : 98.40%
# ⏱ Avg inference / img  : 0.002301 sec
# 🚀 FPS                 : 434.55
