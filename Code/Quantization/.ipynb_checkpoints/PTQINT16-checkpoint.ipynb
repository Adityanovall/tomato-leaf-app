# %%
import tensorflow as tf

# =====================
# LOAD BASELINE MODEL
# =====================
model = tf.keras.models.load_model("baseline_mobilenetv3_final.keras")

# =====================
# TFLITE CONVERTER
# =====================
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Optimisasi default
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# INT16 quantization (weights only)
converter.target_spec.supported_types = [tf.int16]

# Penting: pastikan input-output tetap float
converter.inference_input_type = tf.float32
converter.inference_output_type = tf.float32

# =====================
# CONVERT
# =====================
tflite_int16 = converter.convert()

# =====================
# SAVE MODEL
# =====================
with open("baseline_mobilenetv3_int16.tflite", "wb") as f:
    f.write(tflite_int16)

print("✅ INT16 TFLite model saved")
# Out:
# C:\Users\adity\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 22 variables whereas the saved optimizer has 42 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# INFO:tensorflow:Assets written to: C:\Users\adity\AppData\Local\Temp\tmp194yjaq3\assets
# INFO:tensorflow:Assets written to: C:\Users\adity\AppData\Local\Temp\tmp194yjaq3\assets
# Saved artifact at 'C:\Users\adity\AppData\Local\Temp\tmp194yjaq3'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   1950563966736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563967312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563967888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563968272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563967504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563966544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563970192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563969040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563969424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563968848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563970576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563972496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563971920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563973264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563971728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563973840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563974992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563974032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563974416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563974224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565516304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565515344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950563972688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565515536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565517840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565517456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565517072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565518032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565516688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565520144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565520528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565520912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565520720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565516112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565518992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565522640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565523024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565522832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565519376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565521680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565524752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565525136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565524944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565522064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565526288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565526672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565527056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565526864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565523792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565528208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565528592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565528976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565528784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565524368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565530128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565530512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565531280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565530704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565525904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565529360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565529744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565908752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565910288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565909712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565910864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565911248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565911056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565909328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565912400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565912784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565913168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565912976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565908944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565914320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565914704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565915088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565914896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565910480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565916240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565916816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565915856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565917584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565917008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565918160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565918544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565918352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565913936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565919696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565920080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565920464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565920272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565909520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565921616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565922000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565922384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565922192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565917776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565923536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565924112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565923152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565924496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565921232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566417040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566416464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565919312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950565924688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566418576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566418960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566419344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566419152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566416656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566420496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566420880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566421264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566421072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566417232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566422416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566422992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566422032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566423760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566423184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566424336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566424720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566424528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566420112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566425872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566426256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566426640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566426448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566417424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566427792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566428176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566428560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566428368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566423952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566429712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566430288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566429328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566431056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566430480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566431632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566432400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566431824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566427408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566430864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566859408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566859984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566431248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566859024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566861136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566861520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566861904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566861712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566858832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566863056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566863632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566862672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566864400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566863824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566864976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566865360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566865168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566860752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566866512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566866896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566867280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566867088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566859216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566868432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566868816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566869200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566869008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566864592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566870352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566870928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566869968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566871696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566871120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566872272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566872656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566872464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566868048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566873808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566874192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566874960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566874384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566859600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566866128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567367696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567366736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950566871888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567366928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567369232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567369808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567368848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567370576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567369616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567371536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567371920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567371728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567367120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567373072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567373456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567373840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567373648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567370960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567370768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1950567376144: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ INT16 TFLite model saved

# %%
interpreter = tf.lite.Interpreter(
    model_path="baseline_mobilenetv3_int16.tflite",
    experimental_delegates=[]
)

interpreter.allocate_tensors()

input_details  = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Input :", input_details)
print("Output:", output_details)
# Out:
# Input : [{'name': 'serving_default_input_layer_1:0', 'index': 0, 'shape': array([  1, 224, 224,   3], dtype=int32), 'shape_signature': array([ -1, 224, 224,   3], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Output: [{'name': 'StatefulPartitionedCall_1:0', 'index': 218, 'shape': array([ 1, 10], dtype=int32), 'shape_signature': array([-1, 10], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# C:\Users\adity\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

# =====================
# CONFIG
# =====================
IMG_SIZE = 224
BATCH_SIZE = 16
TEST_DIR = r"C:\Users\adity\Downloads\dataset_split_final\test"

# =====================
# TEST GENERATOR (SAMA DENGAN TRAINING)
# =====================
test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

test_gen = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

print("✅ test_gen ready")
print("Total test samples:", test_gen.samples)
# Out:
# Found 1000 images belonging to 10 classes.
# ✅ test_gen ready
# Total test samples: 1000

# %%
import time
import numpy as np

correct = 0
total = 0
times = []

for i in range(test_gen.samples):
    x_batch, y_batch = next(test_gen)

    x = x_batch[0:1].astype(np.float32)
    y = y_batch[0]

    start = time.time()
    interpreter.set_tensor(input_details[0]["index"], x)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]["index"])
    end = time.time()

    pred = output.argmax(axis=1)[0]
    true = y.argmax()

    correct += int(pred == true)
    total += 1
    times.append(end - start)

accuracy = correct / total
avg_time = sum(times) / len(times)
fps = 1 / avg_time

print("\n✅ INT16 TFLite RESULTS")
print(f"Accuracy            : {accuracy*100:.2f}%")
print(f"Avg inference/image : {avg_time:.6f} sec")
print(f"FPS                 : {fps:.2f}")
# Out:
# ✅ INT16 TFLite RESULTS
# Accuracy            : 98.40%
# Avg inference/image : 0.002296 sec
# FPS                 : 435.48
